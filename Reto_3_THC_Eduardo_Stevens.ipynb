# %%
print("Escriba la hora de la ciudad de Mexico")

#Declaracion de variables para que el usuario ingrese la hora
hor_mex=input("Horas ")
min_mex=input("Minutos ")

#Condicional if para evaluar que el tipo de dato sea el correcto
if hor_mex.isalpha()==False and min_mex.isalpha()==False:

    #Conversion de las variables en enteros
    min_mex=int(min_mex)
    hor_mex=int(hor_mex)

    #Funcon lambda para evaluar el ingraso de las horas y minutos con restriccion de cada valor
    minutos = lambda x: x%60
    horas = lambda x: x%23

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_tokio=horas(hor_mex+15)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    tJ = dict(Pais='Japon',
                Ciudad='Tokio',
                Hora=horas_tokio,
            Minutos=minutos(min_mex),)
    print(tJ)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_pekin=horas(hor_mex+14)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    pC = dict(Pais='China',
          Ciudad='Pekin',
          Hora=horas_pekin,
          Minutos=minutos(min_mex),)
    print(pC)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_dushambe=horas(hor_mex+11)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    dT = dict(Pais='Tayikistan',
            Ciudad='Dusambe',
            Hora=horas_dushambe,
            Minutos=minutos(min_mex),)
    print(dT)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_pert=horas(hor_mex+14)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    pA = dict(Pais='Australia',
             Ciudad='Pert',
              Hora=horas_pert,
              Minutos=minutos(min_mex),)
    print(pA)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_katmandu=horas(hor_mex+11)
    minutos_katmandu=minutos(min_mex+43)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    kN = dict(Pais='Nepal',
          Ciudad='Katmandú',
          Hora=horas_katmandu,
          Minutos=minutos_katmandu,)
    print(kN)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_vilna=horas(hor_mex+8)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    lV = dict(Pais='Vilna',
          Ciudad='Lituania',
          Hora=horas_vilna,
          Minutos=minutos(min_mex),)
    print(lV)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_freetown=horas(hor_mex+6)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    fS = dict(Pais='Sierra Leona',
          Ciudad='Free Town',
          Hora=horas_freetown,
          Minutos=minutos(min_mex),)
    print(fS)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_rio=horas(hor_mex+3)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    rB = dict(Pais='Brazil',
          Ciudad='Rio de Janeiro',
          Hora=horas_rio,
          Minutos=minutos(min_mex),)
    print(rB)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_tegucigalpa=horas(hor_mex)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    tH = dict(Pais='Honduras',
          Ciudad='Tegucigalpa',
          Hora=horas_tegucigalpa,
          Minutos=minutos(min_mex),)
    print(tH)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_kingston=horas(hor_mex+1)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    kJ = dict(Pais='Jamaica',
          Ciudad='Kingston',
          Hora=horas_kingston,
          Minutos=minutos(min_mex),)
    print(kJ)

    #Conversion de las horas al tiempo de la hora de la ciudad
    horas_la=horas(hor_mex-2)
    #Declaracion de diccionario para mostrar la hora de la ciudad junto con su informacion
    lE = dict(Pais='EUA',
          Ciudad='Los Angeles',
          Hora=horas_la,
          Minutos=minutos(min_mex),)
    print(lE)
#Otra opcion del condicional para indicar ingreso de datos equivocado
else:
    print("Tipo de dato incorrecto")
# Out:
# Escriba la hora de la ciudad de Mexico
# Horas 12
# Minutos 23
# {'Pais': 'Japon', 'Ciudad': 'Tokio', 'Hora': 4, 'Minutos': 23}
# {'Pais': 'China', 'Ciudad': 'Pekin', 'Hora': 3, 'Minutos': 23}
# {'Pais': 'Tayikistan', 'Ciudad': 'Dusambe', 'Hora': 0, 'Minutos': 23}
# {'Pais': 'Australia', 'Ciudad': 'Pert', 'Hora': 3, 'Minutos': 23}
# {'Pais': 'Nepal', 'Ciudad': 'Katmandú', 'Hora': 0, 'Minutos': 6}
# {'Pais': 'Vilna', 'Ciudad': 'Lituania', 'Hora': 20, 'Minutos': 23}
# {'Pais': 'Sierra Leona', 'Ciudad': 'Free Town', 'Hora': 18, 'Minutos': 23}
# {'Pais': 'Brazil', 'Ciudad': 'Rio de Janeiro', 'Hora': 15, 'Minutos': 23}
# {'Pais': 'Honduras', 'Ciudad': 'Tegucigalpa', 'Hora': 12, 'Minutos': 23}
# {'Pais': 'Jamaica', 'Ciudad': 'Kingston', 'Hora': 13, 'Minutos': 23}
# {'Pais': 'EUA', 'Ciudad': 'Los Angeles', 'Hora': 10, 'Minutos': 23}

# %%
#Inclusion de la biblioteca random
import random as ra

#Linea para pedir al usuario elegir la opcion
rps_1_2=input("Elige piedra, papel o tijeras ")

#Linea para generar un numero aleatoreo entre 0, 1 o 2
rps_2=ra.randint(0,2)

#Asignacion de numero entero 0, 1 o 2 a la eleccion del usuario tipo string
if rps_1_2=='piedra':
    rps_1=0
elif rps_1_2=='papel':
    rps_1=2
elif rps_1_2=='tijeras':
    rps_1=1
#Indicacion de ingreso equivocado por haber ingresado tipo de dato eqivocado
else:
    print("Seleccion incorrecta")

#Condicional para mostrar la seleccion aleatorea del sistema
if rps_2==0:
    print("Contrincante eligio piedra")
elif rps_2==1:
    print("Contrincante eligio tijeras")
elif rps_2==2:
    print("Contrincante eligio papel")


print()

#Condicional para evaluar la opcion empate en juego
if rps_1==rps_2:
    print("Empate")
#Condicional para evaluar el resultado del juego y desplegarlo en pantalla
else:
    if rps_1==0 and rps_2==1:
        print("Victoria")
    elif rps_1==0 and rps_2==2:
        print("Derrota")
    elif rps_1==1 and rps_2==0:
        print("Derrota")
    elif rps_1==1 and rps_2==2:
        print("Victoria")
    elif rps_1==2 and rps_2==0:
        print("Victoria")
    elif rps_1==2 and rps_2==1:
        print("Derrota")
# Out:
# Elige piedra, papel o tijeras tijeras
# Contrincante eligio papel
#
# Victoria

# %%
#Inclusion de la biblioteca random
import random as ra

#Linea para indicar al usuario iniciar el programa
s=input("Apriete enter para tirar los dados")

#Funcion para obtener numeros aleatoreos entre 1 y 6
r_I=ra.randint(1,6)

#Funcion print para indicar el valor obtenido
print("Salio "+str(r_I))

#Condicional para indicar el resultado del juego
if r_I==1:
    print("Vuelvan a lanzar")
elif r_I==6:
    print("Empatados")
elif r_I==2 or r_I==3:
    print("Gana Iván")
else:
    print("Gana Miguel")
# Out:
# Apriete enter para tirar los dados
# Salio 6
# Empatados
